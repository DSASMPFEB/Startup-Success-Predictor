# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\kevin\startuptalky_funding_2025.csv")
df1
# Out:
#                 name                                          sector  \
# 0        Art Of Time                      Consumer Goods > Retailers
# 1    Sammaan Capital     Financial Services > Consumer and SME Loans
# 2      Freight Tiger                       Consumer > Logistics Tech
# 3      Recyclaro.com  Environment Tech > Solid Waste Management Tech
# 4            GrowXCD     Financial Services > Consumer and SME Loans
# ..               ...                                             ...
# 743           Zoplar                   Medical Equipment Procurement
# 744        Moonrider                           Electric Tractor Tech
# 745       Consint.AI                                      Healthtech
# 746         NapTapGo                          Affordable Hospitality
# 747      KIBI Sports                                     Sports Tech
#
#               city state               funding_total     funding_round  \
# ...

# %%
df2 = pd.read_csv(r"C:\Users\kevin\yourstory_startups_merged.csv")
df2
# Out:
#                                    name  \
# 0                             VTC-India
# 1                           A New India
# 2    Topdeck India Tour Booking Pvt Ltd
# 3              Packers And Movers India
# 4                       India Self News
# ..                                  ...
# 301                         Flora India
# 302             Astra Indo Pharma India
# 303                MBC BACCHAWALA INDIA
# 304                           IndianteQ
# 305                        ZOONIS INDIA
#
#                                                sectors headquarters funding  \
# 0                            Direct-To-Consumer Brands     Jamnagar    $500
# 1                       Software, Technology, Services    New Delhi   $1.0k
# 2                         Consumer, Travel/Hospitality       Jaipur   $1.1k
# 3                                             Services     Vadodara   $2.0k
# 4                                  Media, Social Media        Sidhi  $10.0k
# ...

# %%
df3 = pd.read_csv(r"C:\Users\kevin\Downloads\Startups1.csv")
df3
# Out:
#      Unnamed: 0                Company       City  Starting Year  \
# 0             0          Urban Company    Gurgaon           2014
# 1             1              Classplus      Noida           2018
# 2             2                  Paytm      Noida           2010
# 3             3                   Apna     Mumbai           2019
# 4             4               Razorpay  Bengaluru           2014
# ..          ...                    ...        ...            ...
# 295         295               SafexPay      Thane           2017
# 296         296               Pariksha       Pune           2015
# 297         297                  Fyllo  Bengaluru           2019
# 298         298               CredFlow  New Delhi           2019
# 299         299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders  \
# 0    Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1    Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# ...

# %%
df1.columns
# Out:
# Index(['name', 'sector', 'city', 'state', 'funding_total', 'funding_round',
#        'number_of_investors', 'investors'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['name', 'sectors', 'headquarters', 'funding', 'employee_count'], dtype='object')

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'City', 'Starting Year', 'Founders',
#        'Industries', 'Description', 'No. of Employees', 'Funding Amount in $',
#        'Funding Round', 'No. of Investors'],
#       dtype='object')

# %%
df4 = pd.read_csv(r"C:\Users\kevin\Downloads\startup_cleaned.csv")
df4
# Out:
#             date                       startup                    vertical  \
# 0     2020-09-01                        BYJU’S                      E-Tech
# 1     2020-01-13                        Shuttl              Transportation
# 2     2020-09-01                     Mamaearth                  E-commerce
# 3     2020-02-01  https://www.wealthbucket.in/                     FinTech
# 4     2020-02-01                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2817  2015-04-29                        Tracxn  Startup Analytics platform
# 2818  2015-04-29                          Dazo    Mobile Food Ordering app
# 2819  2015-04-29                      Tradelab  Financial Markets Software
# 2820  2015-04-29                        PiQube   Hiring Analytics platform
# 2821  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                 subvertical       city  \
# ...

# %%
df4.columns
# Out:
# Index(['date', 'startup', 'vertical', 'subvertical', 'city', 'investors',
#        'round', 'amount'],
#       dtype='object')

# %%
df1.rename(columns={
    'name': 'company_name',
}, inplace=True)

df2.rename(columns={
    'name': 'company_name',
    'sectors': 'sector',
    'headquarters': 'city',
    'funding': 'funding_total'
}, inplace=True)

df3.rename(columns={
    'Company': 'company_name',
    'City': 'city',
    'Industries': 'sector',
    'No. of Employees': 'employee_count',
    'Funding Amount in $': 'funding_total',
    'Funding Round': 'funding_round',
    'No. of Investors': 'number_of_investors'
}, inplace=True)

df4.rename(columns={
    'startup': 'company_name',
    'vertical': 'sector',
    'round': 'funding_round',
    'amount': 'funding_total'
}, inplace=True)

# %%
df4['sector'] = df4['sector'].fillna('')
df4['subvertical'] = df4['subvertical'].fillna('')
df4['sector'] = df4.apply(
    lambda row: f"{row['sector']} - {row['subvertical']}" if row['subvertical'] else row['sector'],
    axis=1
)
df4.drop(columns=['subvertical'], inplace=True)

# %%
for df in [df1, df2, df3, df4]:
    df['company_name'] = df['company_name'].str.strip().str.lower()

# %%
common_columns = [
    'company_name', 'sector', 'city', 'state', 'funding_total', 'funding_round',
    'number_of_investors', 'investors', 'employee_count', 'Unnamed: 0',
    'Starting Year', 'Founders', 'Description', 'date'
]

for df in [df1, df2, df3, df4]:
    for col in common_columns:
        if col not in df.columns:
            df[col] = None

# %%
combined_df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# Drop duplicates based on both company_name and location
deduped_df = combined_df.drop_duplicates(subset=['company_name', 'city'], keep='first')

# %%
deduped_df.to_csv('STARTUPDATA.csv', index=False)

# %%
df = pd.read_csv('STARTUPDATA.csv')

# %%
df.head()
# Out:
#       company_name                                          sector  \
# 0      art of time                      Consumer Goods > Retailers
# 1  sammaan capital     Financial Services > Consumer and SME Loans
# 2    freight tiger                       Consumer > Logistics Tech
# 3    recyclaro.com  Environment Tech > Solid Waste Management Tech
# 4          growxcd     Financial Services > Consumer and SME Loans
#
#             city state funding_total funding_round  number_of_investors  \
# 0    Maharashtra   NaN   Undisclosed      Series B                  1.0
# 1          Delhi   NaN           $1B      Post IPO                  2.0
# 2    Maharashtra   NaN        $13.5M      Series C                  2.0
# 3  Uttar Pradesh   NaN           $1M          Seed                  1.0
# 4     Tamil Nadu   NaN        $22.5M      Series B                  2.0
#
#                          investors employee_count  Unnamed: 0  Starting Year  \
# ...

# %%
# Ensure both columns exist and are treated as strings
df['Starting Year'] = df['Starting Year'].astype(str).str.strip()
df['date'] = df['date'].astype(str).str.strip()

# Replace empty strings or 'nan' with None
df['Starting Year'] = df['Starting Year'].replace(['', 'nan', 'NaN'], None)
df['date'] = df['date'].replace(['', 'nan', 'NaN'], None)

# Combine into a new column
df['startup_date'] = df.apply(
    lambda row: row['Starting Year'] if row['Starting Year'] else row['date'],
    axis=1
)

# %%
# Optional: drop the original columns
df.drop(columns=['Starting Year', 'date'], inplace=True)

# %%
manual_dates = {'art of time': '2000', 'sammaan capital': '2005', 'freight tiger': '2014', 'recyclaro.com': '2025', 'growxcd': '2022', 'unmannd': '2025', 'vamam': '2000', 'climaty ai': '2024', 'ignosis': '2022', 'fyno': '2022', 'recur club': '2021', 'wit and chai group': '2020', 'hocco': '2019', 'petpoojam': '2011', 'kapivas': '2015', 'vaani research labs': '2024', 'ef polymer': '2018', 'rugr': '2022', 'igowise': '2020', 'pharmeasy': '2015', 'emergent': '2024', 'chakr innovation': '2016', 'curefoods': '2020', 'handpickd': '2024', 'rocket': '1963', 'vedantu': '2014', 'simple energy': '2019', 'kisankonnect': '2020', 'distil': '2023', 'gullak': '2022', 'oolka': '2024', 'prism': '2013', 'onfinance': '2023', 'amwoodo': '2019', 'cosmoserve space': '2025', 'p-tal': '2017', 'xbattery': '2024', 'vyomic': '2024', 'akashalabdhi': '2023', 'navo': '2025', 'bharat intelligence': '2024', 'recove': '2024', 'paar autonomy': '2024', 'samaaro': '2015', 'gaadimech': '2020', 'gabit': '2022', 'infra.market': '2016', 'evoluteiq': '2019', 'finbox': '2015', 'blue energy motors': '2020', 'incred money': '2015', 'ecosoul': '2021', 'indkal': '2018', 'scalekit': '2023', 'lucira': '2025', 'spacefields': '2021', 'pelocal fintech': '2021', 'ido devices': '2025', 'pascal ai labs': '2024', 'equilibrium': '2011', 'includ': '2023', 'blinkit-ai': '2024', 'supply6': '2019', 'ugx.ai': '2023', 'playsuper': '2024', 'wankel energy systems': '2022', 'mynaksh': '2025', 'uknowva': '2012', 'raptee.hv': '2018', 'flipspaces': '2011', 'indrajaal': '2023', 'presolv360': '2017', 'indigrid technology': '2016', 'ember': '2000', 'asaya': '2021', 'inamo': '2024', 'wehouse': '2017', 'endureair systems': '2018', 'snap-e-cabs': '2022', 'aurva': '2023', 'bacalt biosciences': '2023', 'peakamp': '2024', 'farmdidi': '2021', 'prowrrap': '2024', 'biokraft foods': '2023', 'misfits': '1977', 'traqcheck': '2020', 'citymall': '2019', 'seekho': '2020', 'blue tokai coffee roasters': '2013', 'firstclub': '2024', 'colive': '2016', 'offgrid energy': '2018', 'reveal healthtech': '2023', 'platinumrx': '2023', 'leafybus': '2023', 'tuco kids': '2023', 'flexifyme': '2021', 'autodukan': '2017', 'house of zelena': '2021', 'cuzor': '2019', 'rxmen': '2023', 'quante energy': '2024', 'dectrocel': '2020', 'waterscience': '2014', 'edgehax': '2025', 'transbnk': '2022', 'altum credo': '2016', 'credright': '2016', 'wizcommerce': '2020', 'v
': '2021', 'utsav': '2021', 'medmitra ai': '2023', 'dressfolk': '2015', 'nazara technologies': '1999', 'ati motors': '2017', 'aris infra solutions': '2021', 'deconstruct': '2020', 'vunet systems': '2014', 'medusa beverages': '2017', 'snabbit': '2024', 'landeed': '2022', 'bpr hub': '2024', 'pipeshift': '2024', 'zeelab pharmacy': '2019', 'procureyard': '2023', 'workie': '2017', 'cancrie': '2020', 'raaz app': '2024', 'postudio': '2020', 'chelvies coffee': '2023', 'krvvy': '2023', 'prantae solutions': '2015', 'exsure': '2021', 'dream aerospace': '2022', 'svastek': '2020', 'joyspoon': '2022', 'aragen': '2001', 'netradyne': '2015', 'wework india': '2017', 'foxtale': '2021', 'ecozen': '2010', 'bgauss': '2020', 'micromitti': '2023', 'sarla aviation': '2023', 'skor technologies': '2023', 'astrosure.ai': '2024', 'emiza supply chain services': '2015', 'eccentric': '2012', 'wevois': '2018', 'boba bhai': '2023', 'constelli': '2017', 'fambo': '2022', 'tyreplex': '2020', 'zerocircle': '2020', 'kisaansay': '2023', 'erlysign': '2019', 'orbitaid': '2021', 'greenstitch': '2023', 'parkmate': '2021', 'reput.ai': '2024', 'quash': '2023', 'house of chikankari': '2020', 'tractor factory': '2022', 'sukoon unlimited': '2024', 'indiyanet': '2023', 'innovaccer inc.': '2012', 'oyo': '2012', 'infinity fincorp solutions': '2016', 'botanic healthcare': '2013', 'waycool': '2015', 'grayquest': '2017', 'vehant technologies': '2005', 'mintoak': '2017', 'beyond snack': '2018', 'emo energy': '2022', 'ras': '2017', 'rasa (conversational ai platform)': '2020', 'brainsight ai': '2019', 'hbits': '2022', 'zoplar': '2024', 'consint.ai': '2024', 'kibi sports': '2024'}

    


df['startup_date'] = df['company_name'].map(manual_dates).fillna(df['startup_date'])

# %%
df.isna().sum()
# Out:
# company_name              0
# sector                    1
# city                      0
# state                  3553
# funding_total             0
# funding_round           306
# number_of_investors    2548
# investors               604
# employee_count         2962
# Unnamed: 0             3268
# Founders               3268
# Description            3268
# startup_date            326
# dtype: int64

# %%
df.head(5)
# Out:
#       company_name                                          sector  \
# 0      art of time                      Consumer Goods > Retailers
# 1  sammaan capital     Financial Services > Consumer and SME Loans
# 2    freight tiger                       Consumer > Logistics Tech
# 3    recyclaro.com  Environment Tech > Solid Waste Management Tech
# 4          growxcd     Financial Services > Consumer and SME Loans
#
#             city state funding_total funding_round  number_of_investors  \
# 0    Maharashtra   NaN   Undisclosed      Series B                  1.0
# 1          Delhi   NaN           $1B      Post IPO                  2.0
# 2    Maharashtra   NaN        $13.5M      Series C                  2.0
# 3  Uttar Pradesh   NaN           $1M          Seed                  1.0
# 4     Tamil Nadu   NaN        $22.5M      Series B                  2.0
#
#                          investors employee_count  Unnamed: 0 Founders  \
# ...

# %%
manual_dates = { 'grest':'2018',
'pelocal fintech':'2021',
'zanskar':'2023',
'amama':'2018',
'pop':'2023',
'knest':'2014',
'giks india':'2009',
'mobi india':'2011',
'the wanderer india':'2020',
'salam mirror india':'2019',
'indiadeposit':'2021',
'sokudo electric india':'2023',
'unitile india':'1996',
'ssat india':'2011',
'sands india':'2008',
'skill talks india':'2020',
'getpage india':'2023',
'cfi - coaching foundation india':'2014',
'one india securities':'2018',
'hire help india':'2015',
'al safa demolition contractors india':'2023',
'everbloom india':'2017',
'raj flavours india':'2023',
'ifragrance india':'2022',
'bongchie india':'2018',
'indianvillez':'2019',
'icrl india':'2012',
'sagami india - japanese logistics':'2013',
'swayam india':'2005',
'evable india':'2023',
'modular concepts india':'2015',
'otu india':'2014',
'softrate india':'2023',
'kenstar india':'1996',
'carton india':'2018',
'handycraft india':'2018',
'ab initio india':'2006',
'india flux':'2021',
'agriplex india':'2019',
'evtl india':'2020',
'taj indian':'2022',
'fuelcab india':'2023',
'biobritte india':'2016',
'india thrills':'2019',
'forest essentials india':'2000',
'mc fox india':'2020',
'suthe e-commerce india':'2022',
'ceeon india':'2014',
'blue ocean academy india':'2022',
'motovil india':'2012',
'vacation trip india':'2008',
'india career centre':'2022',
'online legal india':'2019',
'humanity foundation of india':'2003',
'indian corporate gifts':'2012',
'india tourism':'1966',
'ferosh india':'2016',
'gemeria hair india':'2013',
'prodemy india':'2021',
'forethought india':'2022',
'prymus brandcom india':'2017',
'medimove india':'2020',
'pain free india physiotherapy at home':'2020',
'astra indo pharma india':'2022',
'mbc bacchawala india':'2021',
'indianteq':'2021',
'hair originals':'2018',
'pelocal fintech':'2021',
'dpdzero':'2022',
'moonrider private limited':'2023',
'vtc-india':'2008',
'a new india ':'1919',
'topdeck india tour booking private limited':'2023',
'packers and movers india private limited':'2000',
'deskmate global express india private limited':'2012',
'wealth 4 india private limited':'2013',
'adzenia':'2021',
'global colours and chemicals limited':'2017',
'sunsys technologies india pvt. ltd.':'2006',
'amar food products india':'1984',
'esports daily':'2020',
'cleanly':'2012',
'india internets':'2002',
'best of indian products':'2001',
'wdipl ':'2001',
'older first':'2021',
'ritvi steel buildings india private limited':'2019',
'brds india ':'2005',
'ess india ':'1997',
'assesslim':'2022'

 }


df['startup_date'] = df['company_name'].map(manual_dates).fillna(df['startup_date'])

# %%
df
# Out:
#          company_name                                          sector  \
# 0         art of time                      Consumer Goods > Retailers
# 1     sammaan capital     Financial Services > Consumer and SME Loans
# 2       freight tiger                       Consumer > Logistics Tech
# 3       recyclaro.com  Environment Tech > Solid Waste Management Tech
# 4             growxcd     Financial Services > Consumer and SME Loans
# ...               ...                                             ...
# 3549          reglobe                 Used Gadgets Buy / Refurbishing
# 3550          icertis                       Cloud Enterprise Software
# 3551             dazo                        Mobile Food Ordering app
# 3552         tradelab                      Financial Markets Software
# 3553           piqube                       Hiring Analytics platform
#
#                city state funding_total   funding_round  number_of_investors  \
# ...

# %%
df.to_csv("STARTUPDATA.csv", index=False)

# %%
df = pd.read_csv("STARTUPDATA.csv")
